# %% [markdown]
# # Task C Long Short-Term Memory

# %% [markdown]
# ## Import library and funtion

# %%
# import library
import os
import time
import string

import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt

from tqdm import tqdm
from tensorflow import keras
from tensorflow.keras import layers, models
from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score

# %%
# change path
path = os.path.dirname(os.getcwd()) 
os.chdir(path)
print(os.getcwd())

# create saving path
save_path = './Results/C'
if not os.path.exists(save_path):
    os.makedirs(save_path)
# Out:
# C:\Users\Ys1ong\DLNLP_23_SN22082567\Jupyter Code

# %%
# import implemented functions
import NLP as NLP

# %% [markdown]
# ## Data Visualization

# %%
# read data
training_df = pd.read_csv('Datasets/training.csv')
validation_df = pd.read_csv('Datasets/validation.csv')
test_df = pd.read_csv('Datasets/test.csv')

# %%
# map category to label
category = ['sadness', 'joy', 'love', 'anger', 'fear', 'surprise']
labels_dict = {0:'sadness', 1:'joy', 2:'love', 3:'anger', 4:'fear', 5:'surprise'}

training_df['description'] = training_df['label'].map(labels_dict)
validation_df['description'] = validation_df['label'].map(labels_dict)
test_df['description'] = test_df['label'].map(labels_dict)

# %%
# plot distribution of training, validation and test data
training_distribution = NLP.plot_distribution(training_df, 'description', 'Training')
training_distribution.savefig(os.path.join(save_path, '1 Label Distribution of Training Data.png'))

validation_distribution = NLP.plot_distribution(validation_df, 'description', 'Validation')
validation_distribution.savefig(os.path.join(save_path, '2 Label Distribution of Validation Data.png'))

test_distribution = NLP.plot_distribution(test_df, 'description', 'Test')
test_distribution.savefig(os.path.join(save_path, '3 Label Distribution of Test Data.png'))
# Out:
# joy: 5362 (33.51%)
# sadness: 4666 (29.16%)
# anger: 2159 (13.49%)
# fear: 1937 (12.11%)
# love: 1304 (8.15%)
# surprise: 572 (3.57%)
# joy: 704 (35.20%)
# sadness: 550 (27.50%)
# anger: 275 (13.75%)
# fear: 212 (10.60%)
# love: 178 (8.90%)
# surprise: 81 (4.05%)
# joy: 695 (34.75%)
# sadness: 581 (29.05%)
# anger: 275 (13.75%)
# fear: 224 (11.20%)
# love: 159 (7.95%)
# surprise: 66 (3.30%)

# %%
# show training dataframe
training_df
# Out:
#                                                     text  label description
# 0                                i didnt feel humiliated      0     sadness
# 1      i can go from feeling so hopeless to so damned...      0     sadness
# 2       im grabbing a minute to post i feel greedy wrong      3       anger
# 3      i am ever feeling nostalgic about the fireplac...      2        love
# 4                                   i am feeling grouchy      3       anger
# ...                                                  ...    ...         ...
# 15995  i just had a very brief time in the beanbag an...      0     sadness
# 15996  i am now turning and i feel pathetic that i am...      0     sadness
# 15997                     i feel strong and good overall      1         joy
# 15998  i feel like this was such a rude comment and i...      3       anger
# 15999  i know a lot but i feel so stupid because i ca...      0     sadness
#
# [16000 rows x 3 columns]

# %% [markdown]
# ## Data Pre-processing

# %%
# data clearning and get maximum length
print('Start data cleaning ...')
print('Remove all URL links https?:\/\/\S+', )
print('Removing all punctuation', string.punctuation)
print('Convert all letters to lowercase')
    
word2id, max_len = NLP.get_vocab(tqdm(training_df['text'].tolist() + validation_df['text'].tolist()))
# Out:
# Start data cleaning ...
# Remove all URL links https?:\/\/\S+
# Removing all punctuation !"#$%&'()*+,-./:;<=>?@[\]^_`{|}~
# Convert all letters to lowercase
# 100%|██████████| 18000/18000 [00:02<00:00, 6999.69it/s]

# %%
# data tokenization
print('Start data tokenization ...')
X_train = NLP.tokenization(word2id, training_df['text'].tolist(), max_len)
X_valid = NLP.tokenization(word2id, validation_df['text'].tolist(), max_len)
# Out:
# Start data tokenization ...
# 100%|██████████| 16000/16000 [00:02<00:00, 6521.67it/s]
# 100%|██████████| 2000/2000 [00:00<00:00, 6707.75it/s]

# %%
# labels one hot encoding
onehot_encoder = OneHotEncoder(sparse_output = False)
y_train = onehot_encoder.fit_transform(np.array(training_df['label'].tolist()).reshape(-1, 1))
y_valid = onehot_encoder.fit_transform(np.array(validation_df['label'].tolist()).reshape(-1, 1)) 

print('The shape of training dataset is', X_train.shape)
print('The shape of validation dataset is', X_valid.shape)

print('\nThe shape of training label is', y_train.shape)
print('The shape of validation label is', y_valid.shape)
# Out:
# The shape of training dataset is (16000, 66)
# The shape of validation dataset is (2000, 66)
#
# The shape of training label is (16000, 6)
# The shape of validation label is (2000, 6)

# %% [markdown]
# ## Model Training

# %%
# build LSTM model
model_LSTM = models.Sequential()
model_LSTM.add(layers.Embedding(input_dim = len(word2id), output_dim = 100, input_length = max_len))
model_LSTM.add(layers.LSTM(units=64, return_sequences = True, activity_regularizer = keras.regularizers.L2(0.01)))
model_LSTM.add(layers.Dropout(0.2))
model_LSTM.add(layers.LSTM(units = 32, activity_regularizer = keras.regularizers.L2(0.01)))
model_LSTM.add(layers.Dense(6, activation = 'softmax'))
model_LSTM.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 66, 100)           1618900
#
#  lstm (LSTM)                 (None, 66, 64)            42240
#
#  dropout (Dropout)           (None, 66, 64)            0
#
#  lstm_1 (LSTM)               (None, 32)                12416
#
#  dense (Dense)               (None, 6)                 198
#
# =================================================================
# Total params: 1,673,754
# Trainable params: 1,673,754
# Non-trainable params: 0
# _________________________________________________________________

# %%
# compile model
callbacks = [tf.keras.callbacks.EarlyStopping(monitor = 'val_loss', patience = 5, restore_best_weights = True)]

model_LSTM.compile(loss = keras.losses.categorical_crossentropy,
                  optimizer = keras.optimizers.Adam(0.001),
                  metrics = ['accuracy'])

# %%
# training model
start = time.time()
history_LSTM = model_LSTM.fit(X_train, y_train, validation_data = (X_valid, y_valid), epochs = 50, callbacks = callbacks)
end = time.time()

print('\nTime for training LSTM model is: %.2f' %(end - start) + 's')
# Out:
# Epoch 1/50
# 500/500 [==============================] - 10s 10ms/step - loss: 1.4257 - accuracy: 0.3720 - val_loss: 1.1954 - val_accuracy: 0.4545
# Epoch 2/50
# 500/500 [==============================] - 4s 8ms/step - loss: 1.0854 - accuracy: 0.4480 - val_loss: 1.0604 - val_accuracy: 0.4970
# Epoch 3/50
# 500/500 [==============================] - 4s 8ms/step - loss: 1.0386 - accuracy: 0.4774 - val_loss: 1.0227 - val_accuracy: 0.4945
# Epoch 4/50
# 500/500 [==============================] - 4s 8ms/step - loss: 0.9610 - accuracy: 0.5362 - val_loss: 1.2613 - val_accuracy: 0.4090
# Epoch 5/50
# 500/500 [==============================] - 4s 8ms/step - loss: 0.9442 - accuracy: 0.6096 - val_loss: 0.9788 - val_accuracy: 0.6550
# Epoch 6/50
# 500/500 [==============================] - 4s 8ms/step - loss: 0.9717 - accuracy: 0.5617 - val_loss: 0.9848 - val_accuracy: 0.6325
# Epoch 7/50
# 500/500 [==============================] - 4s 8ms/step - loss: 0.9519 - accuracy: 0.5395 - val_loss: 1.0675 - val_accuracy: 0.5200
# Epoch 8/50
# 500/500 [==============================] - 4s 8ms/step - loss: 0.7481 - accuracy: 0.6959 - val_loss: 0.9025 - val_accuracy: 0.7265
# Epoch 9/50
# 500/500 [==============================] - 4s 8ms/step - loss: 0.6703 - accuracy: 0.7567 - val_loss: 0.8565 - val_accuracy: 0.7160
# Epoch 10/50
# 500/500 [==============================] - 4s 9ms/step - loss: 0.8337 - accuracy: 0.6554 - val_loss: 0.9897 - val_accuracy: 0.6295
# Epoch 11/50
# 500/500 [==============================] - 4s 8ms/step - loss: 0.5975 - accuracy: 0.7734 - val_loss: 0.6964 - val_accuracy: 0.7580
# Epoch 12/50
# 500/500 [==============================] - 4s 9ms/step - loss: 0.5050 - accuracy: 0.7958 - val_loss: 0.6749 - val_accuracy: 0.7655
# Epoch 13/50
# 500/500 [==============================] - 4s 9ms/step - loss: 0.4240 - accuracy: 0.8202 - val_loss: 0.5934 - val_accuracy: 0.7880
# Epoch 14/50
# 500/500 [==============================] - 4s 8ms/step - loss: 0.3721 - accuracy: 0.8546 - val_loss: 0.5997 - val_accuracy: 0.8170
# Epoch 15/50
# 500/500 [==============================] - 4s 8ms/step - loss: 0.2931 - accuracy: 0.9129 - val_loss: 0.4998 - val_accuracy: 0.8775
# Epoch 16/50
# 500/500 [==============================] - 4s 9ms/step - loss: 0.2402 - accuracy: 0.9513 - val_loss: 0.4572 - val_accuracy: 0.8865
# Epoch 17/50
# 500/500 [==============================] - 4s 8ms/step - loss: 0.1722 - accuracy: 0.9686 - val_loss: 0.5017 - val_accuracy: 0.8835
# Epoch 18/50
# 500/500 [==============================] - 4s 9ms/step - loss: 0.1499 - accuracy: 0.9729 - val_loss: 0.4815 - val_accuracy: 0.8910
# Epoch 19/50
# 500/500 [==============================] - 4s 9ms/step - loss: 0.1207 - accuracy: 0.9789 - val_loss: 0.3932 - val_accuracy: 0.8945
# Epoch 20/50
# 500/500 [==============================] - 4s 9ms/step - loss: 0.1221 - accuracy: 0.9790 - val_loss: 0.4818 - val_accuracy: 0.8980
# Epoch 21/50
# 500/500 [==============================] - 4s 9ms/step - loss: 0.1229 - accuracy: 0.9787 - val_loss: 0.4948 - val_accuracy: 0.8880
# Epoch 22/50
# 500/500 [==============================] - 4s 8ms/step - loss: 0.1010 - accuracy: 0.9844 - val_loss: 0.4686 - val_accuracy: 0.9010
# Epoch 23/50
# 500/500 [==============================] - 4s 8ms/step - loss: 0.0983 - accuracy: 0.9837 - val_loss: 0.4364 - val_accuracy: 0.8910
# Epoch 24/50
# 500/500 [==============================] - 4s 8ms/step - loss: 0.0896 - accuracy: 0.9856 - val_loss: 0.5256 - val_accuracy: 0.8955
#
# Time for training LSTM model is: 107.84s

# %%
# plot learning curve
learning_curve_LSTM = NLP.plot_learning_curve(history_LSTM, 'LSTM')
learning_curve_LSTM.savefig(os.path.join(save_path, '4 Learn Curve of LSTM.png'))
# Out:
# The Training Accuracy of LSTM is 0.9856
# The Validation Accuracy of LSTM is 0.8955

# %% [markdown]
# ## Model Evaluation

# %%
# prepare test data
print('Start data tokenization ...')
X_test = NLP.tokenization(word2id, test_df['text'].tolist(), max_len)
y_test = test_df['label'].tolist()
# Out:
# Start data tokenization ...
# 100%|██████████| 2000/2000 [00:00<00:00, 6806.01it/s]

# %%
# show the shape of test data and test label
print('The shape of validation dataset is', X_test.shape)
print('The length of training label is', len(y_test))
# Out:
# The shape of validation dataset is (2000, 66)
# The length of training label is 2000

# %%
# evaludte test accuracy
y_pred_LSTM = np.argmax(model_LSTM.predict(X_test), axis = 1)
print('The Test accuracy of BILSTM is %.4f' %(accuracy_score(y_test, y_pred_LSTM)))
# Out:
# 63/63 [==============================] - 1s 3ms/step
# The Test accuracy of BILSTM is 0.9120

# %%
# plot confusion matrix
CM_LSTM = pd.DataFrame(confusion_matrix(y_test, y_pred_LSTM), index = category , columns = category)
print('Confusion Matrix of LSTM:')
print(CM_LSTM)

print('\nClassification Report of LSTM:')
print(classification_report(y_test, y_pred_LSTM))

confusion_matrix_LSTM = NLP.plot_CM_matrix(CM_LSTM, 'Confusion Matrix of LSTM')
confusion_matrix_LSTM.savefig(os.path.join(save_path, '5 Confusion Matrix of LSTM.png'))
# Out:
# Confusion Matrix of LSTM:
#           sadness  joy  love  anger  fear  surprise
# sadness       560    7     2      5     7         0
# joy            12  658    21      0     1         3
# love            2   34   120      1     1         1
# anger          15    4     1    241    14         0
# fear            9    1     1      2   193        18
# surprise        1    9     0      0     4        52
#
# Classification Report of LSTM:
#               precision    recall  f1-score   support
#
#            0       0.93      0.96      0.95       581
#            1       0.92      0.95      0.93       695
#            2       0.83      0.75      0.79       159
#            3       0.97      0.88      0.92       275
#            4       0.88      0.86      0.87       224
#            5       0.70      0.79      0.74        66
#
#     accuracy                           0.91      2000
#    macro avg       0.87      0.87      0.87      2000
# weighted avg       0.91      0.91      0.91      2000

# %%
# save results
test_df['pred_LSTM'] = y_pred_LSTM
test_df['pred_LSTM_discription'] = test_df['pred_LSTM'].map(labels_dict)
test_df.to_csv(os.path.join(save_path, 'result_C.csv'))
